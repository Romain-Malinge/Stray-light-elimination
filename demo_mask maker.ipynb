# %% [markdown]
# # Object masks in images from prompts with SAM 2

# %%
from mask_maker import *

# %%
# INPUTS
folder = './BDD/Reel/Buddha_1/Stray&PS'
taille = 1024
sam_version = "large"

folders = []

# %%
if folders != []:
    for f in folders:
        folder_path = os.path.join(folder, f)
        print(f"\nProcessing folder: {folder_path}")
        mask = make_mask(folder_path, taille, sam_version)
else:
    print(f"\nProcessing folder: {folder}")
    mask = make_mask(folder, taille, sam_version)
# Out:
# Processing folder: ./BDD/Reel/Buddha_1/Stray&PS
# using device: cpu
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 8
#       6 else:
#       7     print(f"\nProcessing folder: {folder}")
# ----> 8     mask = make_mask(folder, taille, sam_version)
#
# File c:\Users\romai\Documents\GitHub\Stray-light-elimination\mask_maker.py:160, in make_mask(folder_path, taille, version)
#     157 predictor.set_image(image1)
#     158 input_point, input_label = get_input_points(image1)
# --> 160 masks, _, _ = predictor.predict(
#     161     point_coords=input_point,
#     162     point_labels=input_label,
#     163     multimask_output=False,
#     164 )
#     166 # Convertir le masque en format uint8
#     167 mask = masks[0].astype(np.uint8)
#
# ...
