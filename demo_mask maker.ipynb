# %% [markdown]
# # Object masks in images from prompts with SAM 2

# %%
from mask_maker import *

# %%
# INPUTS
folder = './BDD/Reel/Buddha_4'
taille_max = 1024
sam_version = "large"

folders = ["PS"]

# %%
for f in folders:
    folder_path = os.path.join(folder, f)
    print(f"\nProcessing folder: {folder_path}")
    mask = make_mask(folder_path, taille_max, sam_version)
# Out:
# Processing folder: ./BDD/Reel/Buddha_4\PS
# [1/17] Resized image DSC_9499.NEF to 1024 x 682
# [2/17] Resized image DSC_9500.NEF to 1024 x 682
# [3/17] Resized image DSC_9501.NEF to 1024 x 682
# [4/17] Resized image DSC_9502.NEF to 1024 x 682
# [5/17] Resized image DSC_9503.NEF to 1024 x 682
# [6/17] Resized image DSC_9504.NEF to 1024 x 682
# [7/17] Resized image DSC_9505.NEF to 1024 x 682
# [8/17] Resized image DSC_9506.NEF to 1024 x 682
# [9/17] Resized image DSC_9507.NEF to 1024 x 682
# [10/17] Resized image DSC_9508.NEF to 1024 x 682
# [11/17] Resized image DSC_9509.NEF to 1024 x 682
# [12/17] Resized image DSC_9510.NEF to 1024 x 682
# [13/17] Resized image DSC_9511.NEF to 1024 x 682
# [14/17] Resized image DSC_9512.NEF to 1024 x 682
# [15/17] Resized image DSC_9513.NEF to 1024 x 682
# [16/17] Resized image DSC_9514.NEF to 1024 x 682
# [17/17] Resized image DSC_9515.NEF to 1024 x 682
# using device: cpu
# [1/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9499_segmented.png
# [2/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9500_segmented.png
# [3/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9501_segmented.png
# [4/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9502_segmented.png
# [5/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9503_segmented.png
# [6/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9504_segmented.png
# [7/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9505_segmented.png
# [8/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9506_segmented.png
# [9/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9507_segmented.png
# [10/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9508_segmented.png
# [11/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9509_segmented.png
# [12/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9510_segmented.png
# [13/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9511_segmented.png
# [14/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9512_segmented.png
# [15/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9513_segmented.png
# [16/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9514_segmented.png
# [17/17] image saved to ./BDD/Reel/Buddha_4\PS_segmented\DSC_9515_segmented.png
