# %% [markdown]
# # Object masks in images from prompts with SAM 2

# %%
from mask_maker import *

# %%
# INPUTS
folder = './data/image'
taille_max = 2048
sam_version = "large"

# %%
mask = make_mask(folder, taille_max, sam_version)
# Out:
# [1/1] Resized image im_test.png to 800 x 787
# using device: cpu
# [1/1] image saved to ./data\image_segmented\im_test_segmented.png
