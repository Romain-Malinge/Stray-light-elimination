# %%
# %pip install torch==1.12.1 opencv-python==4.8.0.74 Pillow==9.0.1 scipy==1.7.1 numpy==1.22.4 timm==0.6.7
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.12.1 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ERROR: No matching distribution found for torch==1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python inference_file.py --path_obj ./DiLiGenT/ballPNG --nb_img 8
# Out:
# /Users/antonin/N7/3A/Projet-long/3d-tests/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ^C
# Traceback (most recent call last):
#   File "/Users/antonin/N7/3A/Projet-long/3d-tests/Uni-MS-PS/Transformer_multi_res_7.py", line 348, in process
#     normal1 = self.forward_stage(imgs=temps_imgs,
#   File "/Users/antonin/N7/3A/Projet-long/3d-tests/Uni-MS-PS/Transformer_multi_res_7.py", line 271, in forward_stage
#     stage_pred = self.Net_stage.forward([temp,
#   File "/Users/antonin/N7/3A/Projet-long/3d-tests/Uni-MS-PS/Transformer_8.py", line 287, in forward
#     x, x_pool = self.forward_stage(x=x,
#   File "/Users/antonin/N7/3A/Projet-long/3d-tests/Uni-MS-PS/Transformer_8.py", line 208, in forward_stage
#     x2 = blk(x2, H1, W1)
# ...
